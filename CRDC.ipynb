# %%
if __name__ == "__main__":                                                      
    import pandas as pd                                                         
    data = pd.read_csv("CRDC2013_14.csv",encoding="Latin-1")

# %%
data
# Out:
#     LEA_STATE                                   LEA_NAME  \
# 0          TX                                 DENTON ISD
# 1          LA                           LAFAYETTE PARISH
# 2          GA                               HENRY COUNTY
# 3          FL                                     MONROE
# 4          OH                        CLARK-SHAWNEE LOCAL
# 5          CA                            SOLEDAD UNIFIED
# 6          MS               LAMAR COUNTY SCHOOL DISTRICT
# 7          AL                            HUNTSVILLE CITY
# 8          MT                              BILLINGS ELEM
# 9          IL                     CITY OF CHICAGO SD 299
# 10         MA                                   LAWRENCE
# 11         IA         SIOUX CENTRAL COMM SCHOOL DISTRICT
# 12         FL                                 PALM BEACH
# 13         IA            SIOUX CITY COMM SCHOOL DISTRICT
# 14         IL                          SARATOGA CCSD 60C
# ...

# %%
race_cols = [col for col in data.columns if 'SCH_ENR' in col]

# %%
race_cols
# Out:
# ['SCH_ENR_HI_M',
#  'SCH_ENR_HI_F',
#  'SCH_ENR_AM_M',
#  'SCH_ENR_AM_F',
#  'SCH_ENR_AS_M',
#  'SCH_ENR_AS_F',
#  'SCH_ENR_HP_M',
#  'SCH_ENR_HP_F',
#  'SCH_ENR_BL_M',
#  'SCH_ENR_BL_F',
#  'SCH_ENR_WH_M',
#  'SCH_ENR_WH_F',
#  'SCH_ENR_TR_M',
#  'SCH_ENR_TR_F',
#  'SCH_ENR_LEP_M',
#  'SCH_ENR_LEP_F',
#  'SCH_ENR_504_M',
#  'SCH_ENR_504_F',
#  'SCH_ENR_IDEA_M',
#  'SCH_ENR_IDEA_F',
#  'DSO_SCH_ENR_HI_M',
#  'DSO_SCH_ENR_HI_F',
#  'DSO_SCH_ENR_AM_M',
#  'DSO_SCH_ENR_AM_F',
#  'DSO_SCH_ENR_AS_M',
#  'DSO_SCH_ENR_AS_F',
#  'DSO_SCH_ENR_HP_M',
#  'DSO_SCH_ENR_HP_F',
#  'DSO_SCH_ENR_BL_M',
#  'DSO_SCH_ENR_BL_F',
#  'DSO_SCH_ENR_WH_M',
#  'DSO_SCH_ENR_WH_F',
#  'DSO_SCH_ENR_TR_M',
#  'DSO_SCH_ENR_TR_F']

# %%
data['total_enrollment'] = data['TOT_ENR_M'] + data['TOT_ENR_F']

# %%
data['total_enrollment']
# Out:
# 0       602
# 1       542
# 2       861
# 3        18
# 4       344
# 5       648
# 6      1336
# 7       353
# 8       408
# 9       595
# 10      522
# 11      233
# 12      869
# 13      290
# 14      785
# 15      431
# 16      349
# 17      534
# 18      459
# 19      286
# 20     1282
# 21      258
# 22      360
# 23      979
# 24      251
# 25     1159
# 26      532
# 27      858
# 28      669
# 29      442
#        ...
# 970     361
# 971     780
# 972     676
# 973     163
# 974     167
# 975     909
# 976     860
# 977     184
# 978     308
# 979     181
# 980     477
# 981     367
# 982       5
# 983    1883
# 984    4024
# 985     609
# 986      60
# 987    1355
# 988      89
# 989     248
# 990     403
# 991     587
# 992     251
# 993     252
# 994     497
# 995     422
# 996     609
# 997    1337
# 998    1136
# 999     104
# Name: total_enrollment, Length: 1000, dtype: int64

# %%
race_cols = ['SCH_ENR_HI_M',
 'SCH_ENR_HI_F',
 'SCH_ENR_AM_M',
 'SCH_ENR_AM_F',
 'SCH_ENR_AS_M',
 'SCH_ENR_AS_F',
 'SCH_ENR_HP_M',
 'SCH_ENR_HP_F',
 'SCH_ENR_BL_M',
 'SCH_ENR_BL_F',
 'SCH_ENR_WH_M',
 'SCH_ENR_WH_F',
 'SCH_ENR_TR_M',
 'SCH_ENR_TR_F',
 'SCH_ENR_LEP_M',
 'SCH_ENR_LEP_F',
 'SCH_ENR_504_M',
 'SCH_ENR_504_F',
 'SCH_ENR_IDEA_M',
 'SCH_ENR_IDEA_F']

# %%
race_cols
# Out:
# ['SCH_ENR_HI_M',
#  'SCH_ENR_HI_F',
#  'SCH_ENR_AM_M',
#  'SCH_ENR_AM_F',
#  'SCH_ENR_AS_M',
#  'SCH_ENR_AS_F',
#  'SCH_ENR_HP_M',
#  'SCH_ENR_HP_F',
#  'SCH_ENR_BL_M',
#  'SCH_ENR_BL_F',
#  'SCH_ENR_WH_M',
#  'SCH_ENR_WH_F',
#  'SCH_ENR_TR_M',
#  'SCH_ENR_TR_F',
#  'SCH_ENR_LEP_M',
#  'SCH_ENR_LEP_F',
#  'SCH_ENR_504_M',
#  'SCH_ENR_504_F',
#  'SCH_ENR_IDEA_M',
#  'SCH_ENR_IDEA_F']

# %%
race_gender_sum = data[race_cols].sum()

# %%
race_gender_sum.sum()
# Out:
# 648752

# %%
all_enrollment = data['total_enrollment'].sum()

# %%
all_enrollment
# Out:
# 520115

# %%
all_enrollment / race_gender_sum.sum()
# Out:
# 0.8017162182158976

# %%
(data[race_cols] / all_enrollment  ) * 100
# Out:
#      SCH_ENR_HI_M  SCH_ENR_HI_F  SCH_ENR_AM_M  SCH_ENR_AM_F  SCH_ENR_AS_M  \
# 0        0.027494      0.034415      0.000385      0.000385      0.002115
# 1        0.008460      0.003845      0.000000      0.000000      0.002115
# 2        0.009613      0.009613      0.000000      0.000385      0.003269
# 3        0.000000      0.002115      0.000000      0.000000      0.000000
# 4        0.000385      0.000961      0.000000      0.000000      0.000385
# 5        0.000000      0.000000      0.000385      0.000000      0.001538
# 6        0.006729      0.006729      0.000385      0.000385      0.002692
# 7        0.002115      0.002115      0.000385      0.000000      0.000000
# 8        0.011920      0.007883      0.004999      0.007883      0.000000
# 9        0.000961      0.000961      0.000385      0.000000      0.000385
# 10       0.034415      0.057487      0.000000      0.000000      0.000385
# 11       0.001538      0.002115      0.000000      0.000000      0.000385
# ...

# %% [markdown]
# # Review expulsions (which refers to when students are kicked out of school permanently). Columns like SCH_DISCWODIS_EXPWOE_HI_M and TOT_DISCWODIS_EXPZT_F contain information on expulsions.
# # Explore gender and race differences in SAT scores. Columns like SCH_SATACT_HI_M contain this information.
# # Figure out the racial and gender breakdowns for different types of schools, such as magnet schools.
# # Determine how many students are in gifted and talented programs, or advanced placement classes.
# # Investigate how racial differences in enrollment change from preschool to high school.
# # Explore school bullying. The SCH_HBDISCIPLINED_DIS_HI_M column contains some of this information.

# %%
data[data['SCH_DISCWODIS_EXPWOE_HI_M'] > 1]
# Out:
#     LEA_STATE                       LEA_NAME  \
# 67         NM     ALBUQUERQUE PUBLIC SCHOOLS
# 126        OH                MT HEALTHY CITY
# 171        TX  AUSTIN ACHIEVE PUBLIC SCHOOLS
# 197        CA              OCEANSIDE UNIFIED
# 210        CA                BANNING UNIFIED
# 331        OH                    PERRY LOCAL
# 374        CA        ALBERT EINSTEIN ACADEMY
# 383        CA              SAN DIEGO UNIFIED
# 657        MI       CASS CITY PUBLIC SCHOOLS
# 685        CA              SAN DIEGO UNIFIED
# 726        CA        NEVADA JOINT UNION HIGH
# 900        CA              VAL VERDE UNIFIED
# 923        NE          SIDNEY PUBLIC SCHOOLS
# 939        WA     OAK HARBOR SCHOOL DISTRICT
#
#                               SCH_NAME      COMBOKEY    LEAID  SCHID  JJ  \
# 67                   EISENHOWER MIDDLE  350006000049  3500060     49  NO
# 126            NORTH ELEMENTARY SCHOOL  390444101347  3904441   1347  NO
# ...

# %%
word_list = ['TE', 'tr', 'Xr']

# %%
word_list = [v.lower() for v in word_list]

# %%
word_list
# Out:
# ['te', 'tr', 'xr']

# %%
from collections import Counter 
d = Counter({'a': 2, 'and': 23, 'this': 14, 'only.': 21, 'is': 2, 'work': 2, 'will': 2, 'as': 2, 'test': 4})

# %%
d.most_common(2)
# Out:
# [('and', 23), ('only.', 21)]

# %%
import read                                                                     
from collections import Counter                                                 
df = read.load_data()                                                           
#print(df.columns)                                                              
                                                                                
string = ""                                                                     
                                                                                
for i in df['headline']:                                                        
    string += str(i)                                                            
                                                                                
word_list = string.split()                                                      
word_list = [v.lower() for v in word_list]                                      
word_count = Counter(word_list)                                                 
print(word_count.most_common(100))                                              
#word_count= dict(word_count)                                                   
#print(word_count)
# Out:
# [('to', 1630), ('the', 1518), ('of', 1168), ('for', 1130), ('a', 1111), ('in', 1015), ('and', 934), ('is', 569), ('on', 550), ('hn:', 536), ('with', 529), ('-', 486), ('your', 461), ('you', 356), ('from', 296), ('new', 232), ('by', 218), ('at', 207), ('are', 205), ('an', 197), ('–', 186), ('how', 172), ('as', 158), ('google', 157), ('that', 156), ('do', 155), ('not', 154), ('web', 153), ('be', 151), ('it', 150), ('app', 147), ('about', 146), ('i', 143), ('what', 135), ('my', 131), ('|', 127), ('data', 119), ('startup', 113), ('get', 108), ('using', 104), ('open', 99), ('will', 99), ('or', 96), ('its', 96), ('out', 94), ('can', 94), ('have', 93), ('we', 91), ('make', 91), ('&', 88), ('free', 86), ('up', 86), ('now', 85), ('one', 84), ('online', 83), ('has', 82), ('mobile', 81), ('this', 80), ('should', 80), ('more', 79), ('android', 78), ('all', 78), ('facebook', 77), ('use', 76), ('first', 76), ('best', 76), ('code', 76), ('into', 75), ('software', 75), ('social', 75), ('just', 69), 
# ...

# %%
def load_data():                                                                
    import pandas as pd                                                         
    hn_data = pd.read_csv("hn_stories.csv", sep=',', names = ["submission_time","upvotes","url","headline"])                                                       
    # print(data['headline'])                                                   
    return data                                                                 
if __name__ == "__main__":                                                      
    load_data()

# %% [markdown]
# # Make a file called domains.py, using the file browser, or the command line.
# Add in the code to read the file hn_stories.csv, and add column names.
# You can think of each domain name as a "word". A domain will look like scala-lang.org, or blog.iweb.com.
# You can use the value_counts method in pandas to count the number of occurrences of each value in a column.
# Print the 100 most submitted domains.
# By default, Pandas only prints 10 rows of a Dataframe or Series. There is a pandas option to make it print more rows (see this thread on Stackoverflow), but there are bugs with it and Series. Instead, just loop through the series and print the index value, and the total. Here's some sample code:
#
# for name, row in domains.items():
#     print("{0}: {1}".format(name, row))
# The above code assumes that the results of running value_counts is assigned to domains.
#
# You can extend this analysis and make it a bit more robust by removing subdomains. For example, blog.iweb.com and iweb.com would be separate domains at the moment, but they are the same. By removing the subdomain, you can turn blog.iweb.com into iweb.com. You can remove the subdomain using the Series.apply and Dataframe.apply methods in pandas.

# %%
# %touch domains.py
# Out:
# UsageError: Line magic function `%touch` not found.

# %%
help()
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> touch
# No Python documentation found for 'touch'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help>
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# ...

# %%
# !touch domains.py

# %%
# !vi domains.py
# Out:
# 7="domains.py" 0L, 0C▽  [>c~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~          
# ...

# %%
import pandas as pd

# %%
# !cat domains.py

# %%
from dateutil import parser
dt = parser.parse("Aug 28 1999 12:00AM").hour

# %%
def get_hour(string):                                                       
        hr = parser.parse(data['submission_time']).hour                         
        return hr

# %%
load_data()
# Out:
#     LEA_STATE                                   LEA_NAME  \
# 0          TX                                 DENTON ISD
# 1          LA                           LAFAYETTE PARISH
# 2          GA                               HENRY COUNTY
# 3          FL                                     MONROE
# 4          OH                        CLARK-SHAWNEE LOCAL
# 5          CA                            SOLEDAD UNIFIED
# 6          MS               LAMAR COUNTY SCHOOL DISTRICT
# 7          AL                            HUNTSVILLE CITY
# 8          MT                              BILLINGS ELEM
# 9          IL                     CITY OF CHICAGO SD 299
# 10         MA                                   LAWRENCE
# 11         IA         SIOUX CENTRAL COMM SCHOOL DISTRICT
# 12         FL                                 PALM BEACH
# 13         IA            SIOUX CITY COMM SCHOOL DISTRICT
# 14         IL                          SARATOGA CCSD 60C
# ...
