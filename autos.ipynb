# %%
import pandas as pd
import numpy as np

autos = pd.read_csv('autos.csv', encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos["price"].unique()
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$385', '$22,200', '$16,995'],
#       dtype=object)

# %%
# Remove $, "," and convert to int dtype with method chaining.

autos["price"] = autos["price"].str.replace("$","").str.replace(",","").astype(int)

# %%
autos["price"].unique()
# Out:
# array([ 5000,  8500,  8990, ...,   385, 22200, 16995])

# %%
#remove km, "," and convert to int
autos["odometer"] = autos["odometer"].str.replace("km", '').str.replace(",","").astype(int)

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.rename({"odometer":"odometer_km"}, axis=1, inplace=True)

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %%
autos["price"].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos["price"].value_counts().sort_index(ascending=False)
# Out:
# 99999999       1
# 27322222       1
# 12345678       3
# 11111111       2
# 10000000       1
# 3890000        1
# 1300000        1
# 1234566        1
# 999999         2
# 999990         1
# 350000         1
# 345000         1
# 299000         1
# 295000         1
# 265000         1
# 259000         1
# 250000         1
# 220000         1
# 198000         1
# 197000         1
# 194000         1
# 190000         1
# 180000         1
# 175000         1
# 169999         1
# 169000         1
# 163991         1
# 163500         1
# 155000         1
# 151990         1
#             ...
# 66             1
# 65             5
# 60             9
# 59             1
# 55             2
# 50            49
# 49             4
# 47             1
# 45             4
# 40             6
# 35             1
# 30             7
# 29             1
# 25             5
# 20             4
# 18             1
# 17             3
# 15             2
# 14             1
# 13             2
# 12             3
# ...

# %%
autos.loc[autos["price"] == 27322222]
# Out:
#                dateCrawled               name  seller offerType     price  \
# 42221  2016-03-08 20:39:05  Leasinguebernahme  privat   Angebot  27322222
#
#         abtest vehicleType  yearOfRegistration  gearbox  powerPS model  \
# 42221  control   limousine                2014  manuell      163    c4
#
#        odometer_km  monthOfRegistration fuelType    brand notRepairedDamage  \
# 42221        40000                    2   diesel  citroen               NaN
#
#                dateCreated  nrOfPictures  postalCode             lastSeen
# 42221  2016-03-08 00:00:00             0       76532  2016-03-08 20:39:05

# %%
autos.loc[autos["price"].between(98500,99999999)]
# Out:
#                dateCrawled                                               name  \
# 514    2016-03-17 09:53:08                   Ford_Focus_Turnier_1.6_16V_Style
# 1878   2016-03-12 16:58:37                                  Porsche_911_Turbo
# 2184   2016-03-06 04:03:08                                   Land_Rover_Vouge
# 2454   2016-03-21 22:51:29                                    Porsche_911_GT3
# 2751   2016-03-15 10:52:35                               Porsche_911___993_4S
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 7402   2016-03-22 19:48:09  Porsche_911_Carrera_4S_Cabrio_PDK__BOSE__NEU__...
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 8232   2016-04-01 21:50:47               Porsche_993_S_Schalter_BRD_neuwertig
# 10500  2016-03-17 12:56:38                                        Porsche_991
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# ...

# %%
autos_p = autos["price"].between(98500,99999999).index

# %%
autos_p
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
autos = autos.drop(autos[autos.price > 98500].index) #drop all rows more than 98500 outliers

# %%
autos["price"].unique().shape
# Out:
# (2308,)

# %%
autos["price"].value_counts().sort_index(ascending=False).head(50)
# Out:
# 98500    1
# 94999    1
# 93911    1
# 93000    2
# 89900    1
# 89000    1
# 88900    1
# 86500    1
# 85000    1
# 84997    1
# 84000    1
# 83000    1
# 82987    1
# 80000    3
# 79999    1
# 79980    1
# 79933    1
# 79500    1
# 78911    1
# 76997    1
# 75997    1
# 75900    1
# 75000    1
# 74999    2
# 74900    3
# 73996    1
# 73900    1
# 73500    1
# 72900    1
# 72600    1
# 72500    1
# 71000    1
# 70850    1
# 70000    1
# 69999    1
# 69997    1
# 69993    1
# 69900    1
# 69500    1
# 68900    1
# 68750    1
# 68500    1
# 68300    1
# 68000    1
# 67911    1
# 67000    1
# 66964    1
# 66500    1
# 65990    1
# 65700    1
# Name: price, dtype: int64

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos = autos.drop(autos[autos.price > 72600].index)

# %%
autos = autos.drop(autos[autos.price == 1].index)

# %%
autos["price"].unique()
# Out:
# array([ 5000,  8500,  8990, ...,   385, 22200, 16995])

# %%
autos["price"].value_counts()
# Out:
# 0        1421
# 500       781
# 1500      734
# 2500      643
# 1200      639
# 1000      639
# 600       531
# 3500      498
# 800       498
# 2000      460
# 999       434
# 750       433
# 900       420
# 650       419
# 850       410
# 700       395
# 4500      394
# 300       384
# 2200      382
# 950       379
# 1100      376
# 1300      371
# 3000      365
# 550       356
# 1800      355
# 5500      340
# 350       335
# 1250      335
# 1600      327
# 1999      322
#          ...
# 4777        1
# 39911       1
# 6792        1
# 35450       1
# 16995       1
# 10830       1
# 3965        1
# 4649        1
# 2570        1
# 13362       1
# 8655        1
# 459         1
# 29          1
# 3125        1
# 4159        1
# 2410        1
# 69993       1
# 22880       1
# 2459        1
# 8495        1
# 2140        1
# 139         1
# 3285        1
# 4201        1
# 410         1
# 3349        1
# 12333       1
# 1930        1
# 25880       1
# 89          1
# ...

# %%
autos = autos.drop(autos[autos.price == 0].index) # removed all with zero price

# %%
autos.loc[autos["price"] == 2]
# Out:
#                dateCrawled                        name  seller offerType  \
# 1171   2016-03-29 17:53:03    Seat_Leon_Spielzeug_Auto  privat   Angebot
# 24413  2016-03-27 22:06:23  Tausch_iPhone_6_gegen_Auto  privat   Angebot
# 30678  2016-04-03 15:45:42     Tuerkisch___Ordnungsamt  privat   Angebot
#
#        price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1171       2  control   limousine                1950  automatik        5
# 24413      2     test         NaN                2015        NaN        0
# 30678      2     test         NaN                2018  automatik        0
#
#       model  odometer_km  monthOfRegistration fuelType           brand  \
# 1171   leon         5000                    0   diesel            seat
# 24413   NaN         5000                    0      NaN  sonstige_autos
# 30678   5er        20000                    5   diesel             bmw
#
#       notRepairedDamage          dateCreated  nrOfPictures  postalCode  \
# ...

# %%
autos.price.describe()
# Out:
# count    48331.000000
# mean      5711.409447
# std       7186.730822
# min          2.000000
# 25%       1250.000000
# 50%       3000.000000
# 75%       7450.000000
# max      72600.000000
# Name: price, dtype: float64

# %%
autos["odometer_km"].unique().shape
# Out:
# (13,)

# %%
autos.odometer_km.describe()
# Out:
# count     48331.000000
# mean     125914.630361
# std       39609.605288
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos.odometer_km.value_counts()
# Out:
# 150000    31302
# 125000     5041
# 100000     2104
# 90000      1732
# 80000      1412
# 70000      1215
# 60000      1147
# 50000      1005
# 40000       808
# 5000        803
# 30000       767
# 20000       750
# 10000       245
# Name: odometer_km, dtype: int64

# %%
#autos.dateCrawled.describe()
autos.yearOfRegistration.describe()
#autos.yearOfRegistration.shape
#autos = autos.drop(autos[autos.yearOfRegistration < 1900].index)   ## remove years with less then 1900 and anything in future
autos = autos.drop(autos[autos.yearOfRegistration > 2016].index)   ## remove years with greater then 2016 and anything in future

# %%
#autos.dateCrawled.value_counts(normalize=True, dropna=False).sort_index(ascending=True)
autos.yearOfRegistration.value_counts(normalize=True, dropna=False).sort_index(ascending=True)
#autos.dateCreated.value_counts(normalize=True, dropna=False).sort_index
# Out:
# 1000    0.000022
# 1001    0.000022
# 1111    0.000022
# 1800    0.000043
# 1910    0.000086
# 1927    0.000022
# 1929    0.000022
# 1931    0.000022
# 1934    0.000043
# 1937    0.000086
# 1938    0.000022
# 1939    0.000022
# 1941    0.000043
# 1943    0.000022
# 1948    0.000022
# 1950    0.000043
# 1951    0.000022
# 1952    0.000022
# 1953    0.000022
# 1954    0.000043
# 1955    0.000022
# 1956    0.000086
# 1957    0.000043
# 1958    0.000086
# 1959    0.000129
# 1960    0.000474
# 1961    0.000129
# 1962    0.000086
# 1963    0.000151
# 1964    0.000258
#           ...
# 1987    0.001550
# 1988    0.002863
# 1989    0.003681
# 1990    0.007340
# 1991    0.007297
# 1992    0.007900
# 1993    0.009127
# 1994    0.013539
# 1995    0.026067
# 1996    0.029338
# 1997    0.041758
# 1998    0.050540
# 1999    0.062121
# 2000    0.067308
# 2001    0.056632
# 2002    0.053382
# 2003    0.058052
# 2004    0.058074
# 2005    0.063003
# 2006    0.057450
# 2007    0.048904
# ...

# %%
top_brand = autos.brand.value_counts().index

# %%
autos.brand.describe()
# Out:
# count          46458
# unique            40
# top       volkswagen
# freq            9835
# Name: brand, dtype: object

# %%
autos[autos["brand"] == "bmw"].price.mean()
# Out:
# 8222.570031298905

# %%
mean_price_dict = {}

for br in top_brand:
    mean_price = autos[autos["brand"] == br].price.mean()
    mean_price_dict[br] = mean_price

# %%
print(sorted(mean_price_dict))
# Out:
# ['alfa_romeo', 'audi', 'bmw', 'chevrolet', 'chrysler', 'citroen', 'dacia', 'daewoo', 'daihatsu', 'fiat', 'ford', 'honda', 'hyundai', 'jaguar', 'jeep', 'kia', 'lada', 'lancia', 'land_rover', 'mazda', 'mercedes_benz', 'mini', 'mitsubishi', 'nissan', 'opel', 'peugeot', 'porsche', 'renault', 'rover', 'saab', 'seat', 'skoda', 'smart', 'sonstige_autos', 'subaru', 'suzuki', 'toyota', 'trabant', 'volkswagen', 'volvo']

# %%
print(mean_price_dict)
# Out:
# {'volkswagen': 5417.3911540416875, 'bmw': 8222.570031298905, 'opel': 2990.7203763010407, 'mercedes_benz': 8471.205133928572, 'audi': 9287.222001489943, 'ford': 3697.299323909035, 'renault': 2442.5953467153286, 'peugeot': 3100.6928057553955, 'fiat': 2818.456066945607, 'seat': 4412.747058823529, 'skoda': 6384.667539267016, 'nissan': 4750.063202247191, 'mazda': 4112.596614950635, 'smart': 3580.2239031770046, 'citroen': 3790.987767584098, 'toyota': 5167.091062394604, 'hyundai': 5376.740899357602, 'sonstige_autos': 10301.925170068027, 'volvo': 4969.774117647059, 'mini': 10613.459657701711, 'mitsubishi': 3405.7780678851177, 'honda': 4119.109589041096, 'kia': 5982.330303030303, 'alfa_romeo': 4100.915857605178, 'suzuki': 4111.572463768116, 'chevrolet': 6709.358490566037, 'porsche': 28790.5914893617, 'chrysler': 3465.743902439024, 'dacia': 5915.528455284553, 'daihatsu': 1636.1965811965813, 'jeep': 11650.5, 'subaru': 3993.212121212121, 'land_rover': 16970.452631578948, 'saab': 3211.64935064935
# ...

# %%
sorted_by_value = sorted(mean_price_dict.items(), key=lambda kv: kv[1])

# %%
print(sorted_by_value)
# Out:
# [('daewoo', 1049.0), ('rover', 1602.2903225806451), ('daihatsu', 1636.1965811965813), ('trabant', 1771.1515151515152), ('renault', 2442.5953467153286), ('lada', 2688.296296296296), ('fiat', 2818.456066945607), ('opel', 2990.7203763010407), ('peugeot', 3100.6928057553955), ('saab', 3211.6493506493507), ('lancia', 3376.22), ('mitsubishi', 3405.7780678851177), ('chrysler', 3465.743902439024), ('smart', 3580.2239031770046), ('ford', 3697.299323909035), ('citroen', 3790.987767584098), ('subaru', 3993.212121212121), ('alfa_romeo', 4100.915857605178), ('suzuki', 4111.572463768116), ('mazda', 4112.596614950635), ('honda', 4119.109589041096), ('seat', 4412.747058823529), ('nissan', 4750.063202247191), ('volvo', 4969.774117647059), ('toyota', 5167.091062394604), ('hyundai', 5376.740899357602), ('volkswagen', 5417.3911540416875), ('dacia', 5915.528455284553), ('kia', 5982.330303030303), ('skoda', 6384.667539267016), ('chevrolet', 6709.358490566037), ('bmw', 8222.570031298905), ('mercedes_benz',
# ...

# %% [markdown]
# # Cheapest car is daewoo
# # expensive car is porsche
# # Volkswagen is average priced but highest selling

# %%
top_10_brand = autos.brand.value_counts().head(10).index

# %%
print(top_10_brand)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat'],
#       dtype='object')

# %%
mean_10_price_dict = {}

for br1 in top_10_brand:
    mean_10_price = autos[autos["brand"] == br1].price.mean()
    mean_10_price_dict[br1] = mean_10_price

# %%
print(mean_10_price_dict)
# Out:
# {'volkswagen': 5417.3911540416875, 'bmw': 8222.570031298905, 'opel': 2990.7203763010407, 'mercedes_benz': 8471.205133928572, 'audi': 9287.222001489943, 'ford': 3697.299323909035, 'renault': 2442.5953467153286, 'peugeot': 3100.6928057553955, 'fiat': 2818.456066945607, 'seat': 4412.747058823529}

# %%
sorted_by_value_10 = sorted(mean_10_price_dict.items(), key=lambda kv: kv[1])

# %%
print(sorted_by_value_10)
# Out:
# [('renault', 2442.5953467153286), ('fiat', 2818.456066945607), ('opel', 2990.7203763010407), ('peugeot', 3100.6928057553955), ('ford', 3697.299323909035), ('seat', 4412.747058823529), ('volkswagen', 5417.3911540416875), ('bmw', 8222.570031298905), ('mercedes_benz', 8471.205133928572), ('audi', 9287.222001489943)]

# %%
bmp_series = pd.Series(mean_10_price_dict).sort_index()

# %%
bmp_series
# Out:
# audi             9287.222001
# bmw              8222.570031
# fiat             2818.456067
# ford             3697.299324
# mercedes_benz    8471.205134
# opel             2990.720376
# peugeot          3100.692806
# renault          2442.595347
# seat             4412.747059
# volkswagen       5417.391154
# dtype: float64

# %%
mean_10_mil_brand = {}

for br2 in top_10_brand:
    mean_10_mil = autos[autos["brand"] == br2].odometer_km.mean()
    mean_10_mil_brand[br2] = mean_10_mil

# %%
print(mean_10_mil_brand)
# Out:
# {'volkswagen': 128695.98373157092, 'bmw': 132638.88888888888, 'opel': 129322.4579663731, 'mercedes_benz': 130981.02678571429, 'audi': 129258.75341445244, 'ford': 124253.22679778734, 'renault': 128188.8686131387, 'peugeot': 127122.30215827338, 'fiat': 117066.94560669456, 'seat': 121029.41176470589}

# %%
mil_series = pd.Series(mean_10_mil_brand).sort_index()

# %%
mil_series
# Out:
# audi             129258.753414
# bmw              132638.888889
# fiat             117066.945607
# ford             124253.226798
# mercedes_benz    130981.026786
# opel             129322.457966
# peugeot          127122.302158
# renault          128188.868613
# seat             121029.411765
# volkswagen       128695.983732
# dtype: float64

# %%
df = pd.DataFrame(data=bmp_series)

# %%
df2 = pd.DataFrame(data=mil_series)

# %%
frame = [df , df2]

pd.concat(frame, axis=1)
# Out:
#                          0              0
# audi           9287.222001  129258.753414
# bmw            8222.570031  132638.888889
# fiat           2818.456067  117066.945607
# ford           3697.299324  124253.226798
# mercedes_benz  8471.205134  130981.026786
# opel           2990.720376  129322.457966
# peugeot        3100.692806  127122.302158
# renault        2442.595347  128188.868613
# seat           4412.747059  121029.411765
# volkswagen     5417.391154  128695.983732

# %%
autos.gearbox.unique()
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
autos.vehicleType.unique()
# Out:
# array(['bus', 'limousine', 'kleinwagen', 'kombi', nan, 'coupe', 'suv',
#        'cabrio', 'andere'], dtype=object)

# %%
autos.fuelType.unique()
# Out:
# array(['lpg', 'benzin', 'diesel', nan, 'cng', 'hybrid', 'elektro',
#        'andere'], dtype=object)

# %%
autos.notRepairedDamage.unique()
# Out:
# array(['nein', nan, 'ja'], dtype=object)

# %%
autos["dateCrawled"] = autos.dateCrawled.str.replace("-", "")

# %%
autos["notRepairedDamage"] = autos.notRepairedDamage.str.replace("nein", "no")
autos["notRepairedDamage"] = autos.notRepairedDamage.str.replace("ja", "yes")
autos["fuelType"] = autos.fuelType.str.replace("benzin", "as")
autos["fuelType"] = autos.fuelType.str.replace("elektro", "electric")
autos["fuelType"] = autos.fuelType.str.replace("andere", "other")
autos["gearbox"] = autos.fuelType.str.replace("manuell", "manual")
autos["gearbox"] = autos.fuelType.str.replace("automatik", "automatic")

# %%
autos
# Out:
#              dateCrawled                                               name  \
# 0      20160326 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      20160404 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      20160326 18:57:24                         Volkswagen_Golf_1.6_United
# 3      20160312 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      20160401 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      20160321 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      20160320 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      20160316 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      20160322 16:51:34                                         Seat_Arosa
# 9      20160316 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 11     20160316 18:45:34                         Mercedes_A140_Motorschaden
# ...

# %%
brand_count = autos["brand"].value_counts(normalize=True)
brand_count
# Out:
# volkswagen        0.211697
# bmw               0.110035
# opel              0.107538
# mercedes_benz     0.096431
# audi              0.086680
# ford              0.070042
# renault           0.047182
# peugeot           0.029919
# fiat              0.025722
# seat              0.018296
# skoda             0.016445
# nissan            0.015326
# mazda             0.015261
# smart             0.014228
# citroen           0.014077
# toyota            0.012764
# hyundai           0.010052
# sonstige_autos    0.009492
# volvo             0.009148
# mini              0.008804
# mitsubishi        0.008244
# honda             0.007857
# kia               0.007103
# alfa_romeo        0.006651
# suzuki            0.005941
# chevrolet         0.005704
# porsche           0.005058
# chrysler          0.003530
# dacia             0.002648
# daihatsu          0.002518
# jeep              0.002282
# subaru            0.002131
# land_rover        0.002045
# saab              0.001657
# ...

# %%
common_brand = brand_count[brand_count > .05].index

# %%
common_brand
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
common_mean_price = {}

for brand in common_brand:
    brand_only = autos[autos["brand"] == brand]
    m_price = brand_only.price.mean()
    common_mean_price[brand] = int(m_price)
    
common_mean_price
# Out:
# {'volkswagen': 5417,
#  'bmw': 8222,
#  'opel': 2990,
#  'mercedes_benz': 8471,
#  'audi': 9287,
#  'ford': 3697}

# %%
brand_info = pd.DataFrame(mil_series,columns=["mil_series"])

# %%
brand_info["bmp_series"] = bmp_series

# %%
brand_info
# Out:
#                   mil_series   bmp_series
# audi           129258.753414  9287.222001
# bmw            132638.888889  8222.570031
# fiat           117066.945607  2818.456067
# ford           124253.226798  3697.299324
# mercedes_benz  130981.026786  8471.205134
# opel           129322.457966  2990.720376
# peugeot        127122.302158  3100.692806
# renault        128188.868613  2442.595347
# seat           121029.411765  4412.747059
# volkswagen     128695.983732  5417.391154
