# %% [markdown]
# # This project is to analyze hacker news. Find out ASK HN and SHOW HN columns and analyze comments and votes count
#     # What time of the day most comments and votes
#     #

# %%
import csv

open_file = open("hacker_news.csv")
read_file = csv.reader(open_file)
list_file = list(read_file)


hn = list_file[1:]
headers = list_file[0]
#print(headers)
#print(hn)

# %%
ask_posts = []
show_posts = []
other_posts = []

for row in hn:
    title = row[1].lower()
    if title.startswith('ask hn'):
        ask_posts.append(row)
    elif title.startswith('show hn'):
        show_posts.append(row)
    else:
        other_posts.append(row)
print(len(ask_posts))
print(len(show_posts))
print(len(other_posts))
# Out:
# 1744
# 1162
# 17194

# %%
total_ask_comments = 0
for row in ask_posts:
    num_comments = int(row[4])
    total_ask_comments += num_comments

avg_ask_comments = total_ask_comments / len(ask_posts)
print(avg_ask_comments)
# Out:
# 14.038417431192661

# %%
total_show_comments = 0
for row in show_posts:
    num_comments = int(row[4])
    total_show_comments += num_comments
    
avg_show_comments = total_show_comments / len(show_posts)
print(avg_show_comments)
# Out:
# 10.31669535283993

# %%
print(show_posts)
# Out:
# [['10627194', 'Show HN: Wio Link  ESP8266 Based Web of Things Hardware Development Platform', 'https://iot.seeed.cc', '26', '22', 'kfihihc', '11/25/2015 14:03'], ['10646440', 'Show HN: Something pointless I made', 'http://dn.ht/picklecat/', '747', '102', 'dhotson', '11/29/2015 22:46'], ['11590768', 'Show HN: Shanhu.io, a programming playground powered by e8vm', 'https://shanhu.io', '1', '1', 'h8liu', '4/28/2016 18:05'], ['12178806', 'Show HN: Webscope  Easy way for web developers to communicate with Clients', 'http://webscopeapp.com', '3', '3', 'fastbrick', '7/28/2016 7:11'], ['10872799', 'Show HN: GeoScreenshot  Easily test Geo-IP based web pages', 'https://www.geoscreenshot.com/', '1', '9', 'kpsychwave', '1/9/2016 20:45'], ['11237259', 'Show HN: Run with Mark (Runkeeper only)', 'http://runwithmark.github.io/#/', '3', '3', 'ecesena', '3/7/2016 5:17'], ['10603601', 'Show HN: Send an email from your shell to yourself without pain', 'https://ping.registryd.com', '4', '1', 'ybrs', '11/2
# ...

# %%
import datetime as dt
result_list = []
for row in ask_posts:
    num_comments = int(row[4])
    created_at = row[6]
    result_list.append([created_at, num_comments])

#print(result_list[1])
counts_by_hour = {}
comments_by_hour = {}

for row in result_list:
    #print(row[0])
    hr = dt.datetime.strptime(row[0], '%m/%d/%Y %H:%M')
    hour = dt.datetime.strftime(hr, '%H')
    #print(hour)
    if hour not in counts_by_hour:
        counts_by_hour[hour] = 1
        comments_by_hour[hour] = num_comments
    else:
        counts_by_hour[hour] += 1
        comments_by_hour[hour] += num_comments
print(comments_by_hour)
print(sorted(comments_by_hour.items()))
print(sorted(counts_by_hour.items()))
# Out:
# {'09': 90, '13': 170, '10': 118, '14': 214, '16': 216, '23': 136, '12': 146, '17': 200, '15': 232, '21': 218, '20': 160, '02': 116, '18': 218, '03': 108, '05': 92, '19': 220, '01': 120, '22': 142, '08': 96, '04': 94, '00': 110, '06': 88, '07': 68, '11': 116}
# [('00', 110), ('01', 120), ('02', 116), ('03', 108), ('04', 94), ('05', 92), ('06', 88), ('07', 68), ('08', 96), ('09', 90), ('10', 118), ('11', 116), ('12', 146), ('13', 170), ('14', 214), ('15', 232), ('16', 216), ('17', 200), ('18', 218), ('19', 220), ('20', 160), ('21', 218), ('22', 142), ('23', 136)]
# [('00', 55), ('01', 60), ('02', 58), ('03', 54), ('04', 47), ('05', 46), ('06', 44), ('07', 34), ('08', 48), ('09', 45), ('10', 59), ('11', 58), ('12', 73), ('13', 85), ('14', 107), ('15', 116), ('16', 108), ('17', 100), ('18', 109), ('19', 110), ('20', 80), ('21', 109), ('22', 71), ('23', 68)]

# %%
dict1 = {'23': 136, '12': 146, '16': 216}

# %%
total = 0
for key in dict1:
    total +=  dict1[key]
print(total)
# Out:
# 498

# %%
print(dict1)
# Out:
# {'23': 136, '12': 146, '16': 216}

# %%
for key in dict1:
    total = total + dict1[key]
print(total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-8f51ca1d0293> in <module>()
#       1 for key in dict1:
# ----> 2     total = total + dict1[key]
#       3 print(total)
#
# NameError: name 'total' is not defined

# %%
del total

# %%
for key in dict1:
    total = total + dict1[key]
print(total)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8f51ca1d0293> in <module>()
#       1 for key in dict1:
# ----> 2     total = total + dict1[key]
#       3 print(total)
#
# NameError: name 'total' is not defined
