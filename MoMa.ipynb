# %%
moma = [['Dress MacLeod from Tartan Sets',
  'Sarah Charlesworth',
  '(American)',
  '(1947)',
  '(2013)',
  '(Female)',
  '1986',
  'Prints & Illustrated Books'],
 ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
  'Pablo Palazuelo',
  '(Spanish)',
  '(1916)',
  '(2007)',
  '(Male)',
  '1978',
  'Prints & Illustrated Books'],
 ['Tailpiece (page 55) from SAGESSE',
  'Maurice Denis',
  '(French)',
  '(1870)',
  '(1943)',
  '(Male)',
  '1889-1911',
  'Prints & Illustrated Books'],
 ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN',
  'Aristide Maillol',
  '(French)',
  '(1861)',
  '(1944)',
  '(Male)',
  '1927-1940',
  'Prints & Illustrated Books'],
 ['97 rue du Bac',
  'Eugène Atget',
  '(French)',
  '(1857)',
  '(1927)',
  '(Male)',
  '1903',
  'Photography'],
 ['Pictorial ornament (folio 11) from WOODCUTS',
  'Antonio Frasconi',
  '(American)',
  '(1919)',
  '(2013)',
  '(Male)',
  '1957',
  'Prints & Illustrated Books'],
 ["Rue de l'Hôtel-de-Ville",
  'Eugène Atget',
  '(French)',
  '(1857)',
  '(1927)',
  '(Male)',
  '1924',
  'Photography'],
 ['Los Angeles Airport',
  'Garry Winogrand',
  '(American)',
  '(1928)',
  '(1984)',
  '(Male)',
  '1978-83',
  'Photography'],
 ['Why Defy from Disasters of Peace',
  'Diane Victor',
  '(South African)',
  '(1964)',
  '',
  '(Female)',
  '2001',
  'Prints & Illustrated Books'],
 ['STILL WATER AND FISH',
  'David Brown Milne',
  '(Canadian)',
  '(1882)',
  '(1953)',
  '(Male)',
  '(1941)',
  'Prints & Illustrated Books'],
 ['In-text plate (folio 11) from LA MÉTROMANIE',
  'Jean Dubuffet',
  '(French)',
  '(1901)',
  '(1985)',
  '(Male)',
  '1949-1950',
  'Prints & Illustrated Books'],
 ['Black Bathroom',
  'Jim Dine',
  '(American)',
  '(1935)',
  '',
  '(Male)',
  '1963',
  'Prints & Illustrated Books'],
 ['In-text plate (page 108) from LYSISTRATA',
  'František Kupka',
  '(Czech)',
  '(1871)',
  '(1957)',
  '(Male)',
  '1908-1911',
  'Prints & Illustrated Books'],
 ['Transcendence. Designs for the Ballet',
  'Franklin Chenault Watkins',
  '(American)',
  '(1894)',
  '(1972)',
  '(Male)',
  '(1934)',
  'Drawings'],
 ['Untitled',
  'Christopher Wool',
  '(American)',
  '(1955)',
  '',
  '(Male)',
  '1997',
  'Prints & Illustrated Books'],
 ['Isadora Duncan',
  'Abraham Walkowitz',
  '(American)',
  '(1878)',
  '(1965)',
  '(Male)',
  '(1931-33)',
  'Drawings'],
 ["L'Avenir de la Propriété",
  'Pierre Alechinsky',
  '(Belgian)',
  '(1927)',
  '',
  '(Male)',
  '1972',
  'Prints & Illustrated Books'],
 ['Arundel Castle from Black Series I',
  'Frank Stella',
  '(American)',
  '(1936)',
  '',
  '(Male)',
  '1967',
  'Prints & Illustrated Books'],
 ['Block fragments from the Samuel Freeman House, Los Angeles, CA',
  'Frank Lloyd Wright',
  '(American)',
  '(1867)',
  '(1959)',
  '(Male)',
  '1923-1924',
  'Architecture & Design'],
 ['Plate (folio 35) from ACORDE',
  'Vicente Rojo',
  '(Spanish)',
  '(1932)',
  '',
  '(Male)',
  '1979',
  'Prints & Illustrated Books'],
 ['Wolf House, Gubin, Poland (Third floor plan)',
  'Ludwig Mies van der Rohe',
  '(American)',
  '(1886)',
  '(1969)',
  '(Male)',
  '1925-1927',
  'Architecture & Design'],
 ['SA. Sovremennaia Arkhitektura (CA. Contemporary Architecture), no. 5',
  'Varvara Stepanova',
  '(Russian)',
  '(1894)',
  '(1958)',
  '(Female)',
  '1929',
  'Prints & Illustrated Books'],
 ['Untitled',
  'Richard Serra',
  '(American)',
  '(1938)',
  '',
  '(Male)',
  '1972',
  'Drawings'],
 ['Research on the Origin',
  'Robert Filliou',
  '(French)',
  '(1926)',
  '(1987)',
  '(Male)',
  '1974',
  'Prints & Illustrated Books'],
 ['Plate (folio 17) from KAFKA',
  'Roger Chancel',
  '(French)',
  '(1898)',
  '(1976)',
  '(Male)',
  '1957',
  'Prints & Illustrated Books'],
 ['Tailpiece (page 35) from SAINTE MONIQUE',
  'Pierre Bonnard',
  '(French)',
  '(1867)',
  '(1947)',
  '(Male)',
  '1920-1930',
  'Prints & Illustrated Books'],
 ['Bowl',
  'Jacqueline Poncelet',
  '(British)',
  '(1947)',
  '',
  '(Female)',
  '1974',
  'Architecture & Design'],
 ['Tailpiece (folio 42 verso) from LES AMOURS',
  'Émile Bernard',
  '(French)',
  '(1868)',
  '(1941)',
  '(Male)',
  '1915',
  'Prints & Illustrated Books'],
 ['Tuileries (vase)',
  'Eugène Atget',
  '(French)',
  '(1857)',
  '(1927)',
  '(Male)',
  '1912',
  'Photography'],
 ['Plate 23 (folio 25) from MALELADE',
  'Georg Baselitz',
  '(German)',
  '(1938)',
  '',
  '(Male)',
  '1988-1990',
  'Prints & Illustrated Books'],
 ['Duplicate of plate from folio 104 (supplementary suite, plate 95) from LA VILLE',
  'Frans Masereel',
  '(Belgian)',
  '(1889)',
  '(1972)',
  '(Male)',
  '1925',
  'Prints & Illustrated Books'],
 ['Untitled', 'Unknown', '()', '', '', '()', 'c. 1925', 'Photography'],
 ['Plate (folio 28) from Six Geometric Figures and All Their Combinations, Volume I',
  'Sol LeWitt',
  '(American)',
  '(1928)',
  '(2007)',
  '(Male)',
  '1980',
  'Prints & Illustrated Books'],
 ['Chamber Music',
  'James Tenney',
  '(American)',
  '(1934)',
  '(2006)',
  '(Male)',
  '1964',
  'Prints & Illustrated Books'],
 ['Plate (following folio V) from NOTES',
  'Claes Oldenburg',
  '(American)',
  '(1929)',
  '',
  '(Male)',
  '1968',
  'Prints & Illustrated Books'],
 ['Chocolate Object (Schokolade-Objekt)',
  'Dieter Roth',
  '(Swiss)',
  '(1930)',
  '(1998)',
  '(Male)',
  '1969',
  'Prints & Illustrated Books'],
 ["Mandry Ven'iamyna Tret'oho",
  'Moisei Fradkin',
  '()',
  '',
  '',
  '(Male)',
  '1934',
  'Prints & Illustrated Books'],
 ['Dust jacket front (duplicate of folder front) from 2 POEMAS',
  'Antonio Frasconi',
  '(American)',
  '(1919)',
  '(2013)',
  '(Male)',
  '1953',
  'Prints & Illustrated Books'],
 ['Fun City from Fun City',
  'Richard Lindner',
  '(American)',
  '(1901)',
  '(1978)',
  '(Male)',
  '1971',
  'Prints & Illustrated Books'],
 ['Angels from Witebsk',
  'Wojciech Prazmowski',
  '(Polish)',
  '(1949)',
  '',
  '(Male)',
  '1988',
  'Photography'],
 ['Tailpiece (page 62) from FABLES',
  'Thomas Bewick',
  '(British)',
  '(1753)',
  '(1828)',
  '(Male)',
  '1818',
  'Prints & Illustrated Books'],
 ['Untitled',
  'Spencer Sweeney',
  '(American)',
  '(1973)',
  '',
  '(Male)',
  '2002',
  'Drawings'],
 ['Variety',
  'Batiste Madalena',
  '(American)',
  '(1902)',
  '(1988)',
  '(Male)',
  '1926',
  'Film'],
 ['Stars and Disasters (Astres et Désastres)',
  'Pierre Alechinsky',
  '(Belgian)',
  '(1927)',
  '',
  '(Male)',
  '1969',
  'Prints & Illustrated Books'],
 ['U.S. Embassy Building, Tokyo Project (Aerial perspective)',
  'Frank Lloyd Wright',
  '(American)',
  '(1867)',
  '(1959)',
  '(Male)',
  '1914',
  'Architecture & Design'],
 ['Tuesday, Dec. 18, 1979',
  'On Kawara',
  '(Japanese)',
  '(1933)',
  '',
  '(Male)',
  '1979',
  'Painting & Sculpture'],
 ['Bank by Andy Warhol. Gaudy Savings by RCA Color Scanner. Pretty as a Pigture, Huh?',
  'Andy Warhol',
  '(American)',
  '(1928)',
  '(1987)',
  '(Male)',
  '1968',
  'Architecture & Design'],
 ['Pittsburgh, Pennsylvania',
  'Lee Friedlander',
  '(American)',
  '(1934)',
  '',
  '(Male)',
  '1979',
  'Photography'],
 ['Double page plate (between pages 96 and 97) from UBU ROI',
  'Joan Miró',
  '(Spanish)',
  '(1893)',
  '(1983)',
  '(Male)',
  '1966',
  'Prints & Illustrated Books'],
 ['Unity Temple, Oak Park, IL',
  'Frank Lloyd Wright',
  '(American)',
  '(1867)',
  '(1959)',
  '(Male)',
  '1904',
  'Architecture & Design'],
 ['PORTRAITS DE CHOPIN',
  'Marc Chagall',
  '(French)',
  '(1887)',
  '(1985)',
  '(Male)',
  '1949',
  'Prints & Illustrated Books'],
 ['The Razorback Bunch (Etching III)',
  'Robert Rauschenberg',
  '(American)',
  '(1925)',
  '(2008)',
  '(Male)',
  '1981',
  'Prints & Illustrated Books'],
 ['Identity Transfer from Program One: Aspen Projects',
  'Dennis Oppenheim',
  '(American)',
  '(1938)',
  '(2011)',
  '(Male)',
  '1970',
  'Media and Performance Art'],
 ['Lipstick (Ascending) on Caterpillar Track',
  'Claes Oldenburg',
  '(American)',
  '(1929)',
  '',
  '(Male)',
  '1969',
  'Prints & Illustrated Books'],
 ['"1 PERSON/1 PLACE" from the portfolio DETAILS FROM THE EXCAVATION OF WOOSTER STREET',
  'Richard Nonas',
  '(American)',
  '(1936)',
  '',
  '(Male)',
  '1972',
  'Prints & Illustrated Books'],
 ['Bagatelle',
  'Eugène Atget',
  '(French)',
  '(1857)',
  '(1927)',
  '(Male)',
  '1923-25',
  'Photography'],
 ['The Barbie Doll Drawings #27',
  'Adrian Piper',
  '(American)',
  '(1948)',
  '',
  '(Female)',
  '1967',
  'Drawings'],
 ['Gericke House, project, Berlin-Wannsee, Germany, Landscape model',
  'Ludwig Mies van der Rohe',
  '(American)',
  '(1886)',
  '(1969)',
  '(Male)',
  '1932',
  'Architecture & Design'],
 ['Plate (page 209) from LES PETITES FLEURS',
  'Émile Bernard',
  '(French)',
  '(1868)',
  '(1941)',
  '(Male)',
  '1928',
  'Prints & Illustrated Books'],
 ['Mechanical for Ticket for Fluxorchestra at Carnegie Hall, Carnegie Recital Hall, New York, September 25, 1965',
  'George Maciunas',
  '(American)',
  '(1931)',
  '(1978)',
  '(Male)',
  '1965',
  'Prints & Illustrated Books'],
 ['Untitled',
  'Louise Bourgeois',
  '(American)',
  '(1911)',
  '(2010)',
  '(Female)',
  '2003',
  'Prints & Illustrated Books'],
 ['Banco Pinto & Sotto Mayor, Oliveira de Azeméis, Portugal, Plan sketch',
  'Álvaro Siza',
  '(Portuguese)',
  '(1933)',
  '',
  '(Male)',
  '1971-1974',
  'Architecture & Design'],
 ['Overcast Dusk-Glassy Lake from Loon Lake: Eleven Drawings',
  'Ellen Phelan',
  '(American)',
  '(1943)',
  '',
  '(Female)',
  '1983',
  'Drawings'],
 ['Golf Club Project, Krefeld, Germany',
  'Ludwig Mies van der Rohe',
  '(American)',
  '(1886)',
  '(1969)',
  '(Male)',
  '1930',
  'Architecture & Design'],
 ['Stamp Box',
  'Josef Hoffmann',
  '(Austrian)',
  '(1870)',
  '(1956)',
  '(Male)',
  '1946',
  'Architecture & Design'],
 ['Library, Villeurbanne, France, Interior rear elevation',
  'Mario Botta',
  '(Swiss)',
  '(1943)',
  '',
  '(Male)',
  '1984',
  'Architecture & Design']]

# %%
test_data = ["1912", "1870-79", "1929",
             "1913\\-1923", "(1951)", "1994",
             "1934", "c. 1915", "2009", "1978",
             "1947", "1995", "c. 1912",
             "(1988)", "2002", "1957-1959",
             "1964\\-65", "c. 1955.",
             "c. 1970's", "C. 1990-1999"]

bad_chars = ["(",")","c","C",".","\\","s","'"]

def strip_characters(string): # Input a string
    for bchar in bad_chars:   # each item in list
        string = string.replace(bchar, "")
    string = string.strip()
    return string

stripped_test_data = []
for row in test_data:   # loop each item in list
    date = strip_characters(row) # takes a string which comes from test_data
    #date = date.strip()
    stripped_test_data.append(date)
print(stripped_test_data)
# Out:
# ['1912', '1870-79', '1929', '1913-1923', '1951', '1994', '1934', '1915', '2009', '1978', '1947', '1995', '1912', '1988', '2002', '1957-1959', '1964-65', '1955', '1970', '1990-1999']

# %%
def process_date(row):
    total = 0
    #for row in string:
    if "-" in row:
        row = row.split("-")
        if len(row[1]) == 2:
            row[1] = row[0][:2] + row[1]
            row = int(row[0]) + int(row[1])
            row = round(row / 2)
        else:
            row = int(row[0]) + int(row[1])
            row = round(row / 2)
    else:
        row = int(row)
    return row

processed_test_data = []


for sd in stripped_test_data:
    #print(sd)
    df = process_date(sd)
    processed_test_data.append(df)
    processed_test_data
    

for mm in moma:
    #print(sd)
    dat = mm[6]
    dat = strip_characters(dat)
    dat = process_date(dat)
    mm[6] = dat

# %%
import csv

# Read the `artworks_clean.csv` file
f = open('artworks_clean.csv')
reader = csv.reader(f)
moma = list(reader)
moma = moma[1:]

# Convert the birthdate values
for row in moma:
    birth_date = row[3]
    if birth_date != "":
        birth_date = int(birth_date)
    row[3] = birth_date
    
# Convert the death date values
for row in moma:
    death_date = row[4]
    if death_date != "":
        death_date = int(death_date)
    row[4] = death_date

# Write your code below

for row in moma:
    date = row[6]
    if date != "":
        date = int(date)
    row[6] = date

# %%
age = 24
age = str(age)[:-1] + "0s"

print(age)
# Out:
# 20s

# %%
decades = []

for row in moma:
    date = row[6]
    birth = row[3]
    if birth != "":
        artist_age = date - birth
        if artist_age < 20:
            decade = "Unknown"
        else:
            decade = str(artist_age)[:-1] + "0s"
    else:
        decade = "Unknown"
    decades.append(decade)


decade_summary = calculate_decades(decades)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-d9a4ece6456c> in <module>()
#       5     birth = row[3]
#       6     if birth != "":
# ----> 7         artist_age = date - birth
#       8         if artist_age < 20:
#       9             decade = "Unknown"
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
def parse_birth_year(artist):
    """
    For a given artist, return the birth year on the first
    artwork found.
    """
    for row in moma:
        if row[1] == artist:
            birth_date = row[3]
            if birth_date == "":
                birth_date = "unknown"
            return birth_date

print(parse_birth_year("Louise Bourgeois"))

def artist_summary(artist):
    year = parse_birth_year(artist)
    outp = "{}'s birth year is {}".format(artist, year)
    return outp
                     
print(artist_summary("Louise Bourgeois"))
# Out:
# (1911)
# Louise Bourgeois's birth year is (1911)

# %%
mydict = {'a':1, 'b':2}

d = mydict['a']

print(d)
# Out:
# 1

# %%
def widest_key_value(dictionary):
    """
    Returns the width of the string representation
    for the longest key and value in the dict.
    """
    max_key_width = 0
    max_val_width = 0

    for key, value in dictionary.items():
        key_width = len(str(key))
        val_width = len(str(value))
        
        if key_width > max_key_width:
            max_key_width = key_width
        
        if val_width > max_val_width:
            max_val_width = val_width

    return max_key_width, max_val_width

def print_for(num):
    freq_table = {}
    for row in moma:
        col = row[num]
        if col in freq_table:
            freq_table[col] += 1
        else:
            freq_table[col] = 1
    key_width, val_width = widest_key_value(freq_table)
    val_width += 1
    for cat, count in sorted(freq_table.items()):
        
        print("{:<{}} : {:>{},}".format(cat, key_width, count, val_width)) 
    
print_for(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-229-d34cb9a6d0e1> in <module>()
#      33         print("{:<{}} : {:>{},}".format(cat, key_width, count, val_width))
#      34
# ---> 35 print_for(7)
#      36
#
# <ipython-input-229-d34cb9a6d0e1> in print_for(num)
#      22     freq_table = {}
#      23     for row in moma:
# ---> 24         col = row[num]
#      25         if col in freq_table:
#      26             freq_table[col] += 1
#
# TypeError: 'int' object is not subscriptable

# %%
# screen is copied here for your convenience

class SuperList():
    """
    A Python list with some extras!
    """
    def __init__(self, initial_state=[]):
        self._data = initial_state
        self._update()
      
    def __repr__(self):
        string_representation = str(self._data)
        return string_representation
  
    def __eq__(self, other):
        is_equal = self.__dict__ == other.__dict__
        return is_equal
  
    def _calc_length(self):
        """
        A helper function to caluclate the .length
        attribute
        """
        length = 0
        for item in self._data:
            length += 1
        self.length = length
  
    def _calc_max(self):
        """
        A helper function to calculate the .max
        attribute.
        """
        is_empty = len(self._data) == 0
      
        types = []
        for i in self._data:
            i_type = type(i)
            if i_type not in types:
                types.append(i_type)
        more_than_one_type = len(types) > 1

        if is_empty or more_than_one_type:
            self.max = None
        else:
            self.max = max(self._data)
  
    def _calc_min(self):
        """
        A helper function to calculate the .min
        attribute.
        """
        is_empty = len(self._data) == 0
      
        types = []
        for i in self._data:
            i_type = type(i)
            if i_type not in types:
                types.append(i_type)
        more_than_one_type = len(types) > 1

        if is_empty or more_than_one_type:
            self.min = None
        else:
            self.min = min(self._data)
          
    def _calc_types(self):
        """
        A helper function to calculate the .types
        attribute
        """
        types = []
        for item in self._data:
            item_type = type(item)
            if item_type not in types:
                types.append(item_type)
        self.types = types

    def _update(self): 
        """
        A helper method to call other helper methods
        and update attributes when underlying
        data changes.
        """
        self._calc_length()
        self._calc_min()
        self._calc_max()
        self._calc_types()
  
    def append(self, new_item):
        """
        Append `new_item` to the SuperList
        """
        self._data = self._data + [new_item]
        self._update()
  
    def reverse(self):
        """
        Reverse the order of items in the SuperList
        """
        self._data = self._data[::-1]
        self._update()
    def info(self):
        
        template = '''\
List Length:     {}
Max Value:       {}
Min Value:       {}
Types Contained: {}
'''
        info = template.format(self.length,
                               self.max,
                               self.min,
                               self.types)
        print(info)
              
a = SuperList([1, 2, 3, 4, 5])
a.info()
              
b = SuperList([1.3, -14, "hello"])

b.info()
# Out:
# List Length:     5
# Max Value:       5
# Min Value:       1
# Types Contained: [<class 'int'>]
#
# List Length:     3
# Max Value:       None
# Min Value:       None
# Types Contained: [<class 'float'>, <class 'int'>, <class 'str'>]
