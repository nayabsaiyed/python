'2015-01-15T00:00:00', datetime.datetime(2015, 1, 16, 15, 30), '1/16/15 23:59', '', 'POTUS', 'ww/Oval Of', ''], ['Jacob A. Rosenwasser', '2015-01-15T00:00:00', datetime.datetime(2015, 1, 16, 15, 30), '1/16/15 23:59', '', 'POTUS', 'ww/Oval Of', ''], ['DONALD A. HOLLAND', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['NINA M. WELLS', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['CORNELL W. BROOKS', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['AMABEL B. JAMES', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['URSULA M. BURNS', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['MEGAN E. COLLIGAN', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['COLMAN J. DOMINGO', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['AVA DUVERNAY', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['Carmen E. Ejogo', '2015-01-15T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['PAUL G. GARNES', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['BRAD A. GREY', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['KIMBERLEY A. HATCHETT', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['DEBORAH D. HUTCHINS', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['GLENN H. HUTCHINS', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['SHERRILYN A. IFILL', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['HAMILTON E. JAMES', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['STEPHAN JAMES', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['VALERIE B. JARRETT', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['GAYLE KING', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['JEREMY D. KLEINER', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['IVO KNOBLOCH', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['CHARLES J. KRAMER', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['ORIN S. KRAMER', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['JOHN LEWIS', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['LONNIE R. LYNN', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['TRACY V. MAITLAND', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['LORRAINE TOUSSAINT', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['GK BUTTERFIELD', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['HERTHA J. BROOKS', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['MARTIN H. NESBITT', '2015-01-15T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['ASHER O. OYELOWO', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['DARLENE MAYE', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['MURRAY MAYE', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['NANCY A. MORALES', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['OPRAH G. WINFREY', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['BRADFORD M. YOUNG', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['DAVID M. RUBENSTEIN', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['TERRI SEWELL', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['TIMOTHY S. ROTH', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['THEODORE V. WELLS', '2015-01-14T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['JESSICA R. OYELOWO', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['STEPHEN O. OYELOWO', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['LLOYD F. BEAN', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['SPENCER H. AVERICK', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['DORCAS W. GARDNER', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['DAVID O. OYELOWO', '2015-01-13T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['ANITA K. BLANCHARD', '2015-01-15T00:00:00', datetime.datetime(2015, 1, 16, 16, 0), '1/16/15 23:59', '', 'POTUS/FLOTUS', 'State Floo', ''], ['Mitchell Malasky', '2015-01-18T00:00:00', datetime.datetime(2015, 1, 19, 15, 0), '1/19/15 23:59', '', 'POTUS', 'Doctors Of', ''], ['Judy C. Woodruff', '2015-01-17T00:00:00', datetime.datetime(2015, 1, 20, 12, 0), '1/20/15 23:59', '', 'POTUS', 'State Floo', '']]

# %%
import datetime as dt

for row in potus:
    app_st_dt = row[2]
    app_st_dt = dt.datetime.strptime(app_st_dt, '%m/%d/%y %H:%M')
    row[2] = app_st_dt
    print(app_st_dt)
print(row[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-79d8085ab08a> in <module>()
#       3 for row in potus:
#       4     app_st_dt = row[2]
# ----> 5     app_st_dt = dt.datetime.strptime(app_st_dt, '%m/%d/%y %H:%M')
#       6     row[2] = app_st_dt
#       7     print(app_st_dt)
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
dt_object = dt.datetime(1984, 12, 24)
day = dt_object.day
month = dt_object.month
year = dt_object.year
dt_string = '{}/{}/{}'.format(day,month,year)
print(day,month,year)
print(dt_string)
# Out:
# 24 12 1984
# 24/12/1984

# %%
from datetime import datetime as dt

visitors_per_month = {}

for row in potus:
    start_date = row[2]
    start_date = dt.strftime(start_date, '%d %B, %Y')
    if start_date in visitors_per_month:
        visitors_per_month[start_date] += 1
    else:
        visitors_per_month[start_date] = 1
print(visitors_per_month)
# Out:
# {'06 January, 2015': 139, '07 January, 2015': 4, '08 January, 2015': 37, '10 January, 2015': 13, '12 January, 2015': 286, '13 January, 2015': 23, '14 January, 2015': 2, '15 January, 2015': 12, '16 January, 2015': 182, '19 January, 2015': 1, '20 January, 2015': 1}

# %%
print(potus)

# %%
appt_times = {}

for row in potus:
    appt_dt = row[2]
    
    appt_t = appt_dt.time()
    
    if appt_t in appt_times:        
        appt_times[appt_t] += 1
    else:
        appt_times[appt_t] = 1
        
    
min_time = min(appt_times)
max_time = max(appt_times)
print(max_time)
print(min_time)
# Out:
# 19:00:00
# 09:00:00

# %%
import datetime
date_freq = {}

for row in potus:
    appt_date = row[2]
    appt_dt = appt_date.date()
    
    print(appt_dt)

# %%
import datetime as dt
d2_dt = dt.datetime(1946, 9, 10)
d2 = d2_dt.date()
print(d2)
# Out:
# 1946-09-10

# %%
import datetime

for row in potus:
    end_date = datetime.datetime.strptime(row[3],'%m/%d/%y %H:%M')
    row[3] = end_date
    
appt_lengths = []
for row in potus:
    
    timedelta = row[3] - row[2]
    appt_lengths.append(timedelta)

min_length = min(appt_lengths)
max_length = max(appt_lengths)
total_lengths = sum(appt_lengths, datetime.datetime.timedelta(0))
avg_length = total_lengths / len(appt_lengths)
    
print(avg_length)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-02f057d29a94> in <module>()
#       2
#       3 for row in potus:
# ----> 4     end_date = datetime.datetime.strptime(row[3],'%m/%d/%y %H:%M')
#       5     row[3] = end_date
#       6
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
#from datetime import datetime as dt

def appt_summary(string):
    input_date = dt.strptime(string, '%Y, %m, %d' )
    input_date = dt.date(input_date)
    print("Appointments for {:%A %B %-d, %Y}:\n".format(input_date))
    template = "{} at {:%-I:%M %p}."
    for row in potus:
        visitee = row[0].title()
        appt_time = row[2]
        if appt_time.date() == input_date:
            print(template.format(visitee,appt_time))
                  
appt_summary("2015, 5, 20")
# Out:
# Appointments for Wednesday May 20, 2015:

# %%
print(dt.fromtimestamp(60))
# Out:
# 1969-12-31 18:01:00

# %%
print(dt.fromtimestamp(86400))
# Out:
# 1970-01-01 18:00:00

# %%
epochs = [
           ['first', 1139444034],
           ['second', 1430583565],
           ['third', 1318037820],
           ['fourth', 751652064]
         ]

# %%
print(epochs)
# Out:
# [['first', 1139444034], ['second', 1430583565], ['third', 1318037820], ['fourth', 751652064]]

# %%
print(epochs[1][1])
# Out:
# 1430583565

# %%
for row in epochs:
    row[1] = dt.fromtimestamp(row[1])

# %%
print(epochs)
# Out:
# [['first', datetime.datetime(2006, 2, 8, 18, 13, 54)], ['second', datetime.datetime(2015, 5, 2, 11, 19, 25)], ['third', datetime.datetime(2011, 10, 7, 20, 37)], ['fourth', datetime.datetime(1993, 10, 26, 11, 14, 24)]]
